# %% [markdown]
# ### 1. Imports

# %%
import os
import sys
import subprocess
from pathlib import Path
import random
import time # Added for timing
import pandas as pd
import numpy as np # Added for stats
from PIL import Image
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.transforms as T
import timm

# Try importing thop for FLOPs calculation
try:
    from thop import profile
except ImportError:
    print("Please install thop: pip install thop")
    profile = None

# Plottings
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# %% [markdown]
# ### 2. Globals & hyperparameters

# %%
DATA_DIR = Path('data/images')
CSV_PATH = DATA_DIR / '0_data.csv'
IMG_SIZE = 256
BATCH_SIZE = 16
NUM_WORKERS = 4
EPOCHS = 10
LR = 3e-4
VAL_SPLIT = 0.2
SEED = 42
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### 3. Utils

# %%
random.seed(SEED)
torch.manual_seed(SEED)

def read_metadata(csv_path: Path):
    df = pd.read_csv(csv_path)
    return list(df.itertuples(index=False, name=None))

# %% [markdown]
# ### 4. Dataset

# %%
class FeedingDataset(Dataset):
    def __init__(self, meta, img_dir, train=True):
        self.img_dir = img_dir
        self.samples = meta
        aug = [T.RandomResizedCrop(IMG_SIZE, scale=(0.8, 1.0)), T.RandomHorizontalFlip()]
        self.transform = T.Compose([ *(aug if train else [T.Resize((IMG_SIZE, IMG_SIZE))]), T.ToTensor(), T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]), ])

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        label, fname = self.samples[idx]
        img = Image.open(self.img_dir / fname).convert('RGB')
        img = self.transform(img)
        return img, torch.tensor(label, dtype=torch.long)

meta = read_metadata(CSV_PATH)
val_len = int(len(meta) * VAL_SPLIT)
train_len = len(meta) - val_len
train_meta, val_meta = random_split(meta, [train_len, val_len])
train_ds = FeedingDataset(train_meta, DATA_DIR, train=True)
val_ds = FeedingDataset(val_meta, DATA_DIR, train=False)
train_dl = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
val_dl = DataLoader(val_ds, batch_size=BATCH_SIZE, num_workers=NUM_WORKERS)

# %% [markdown]
# ### 5. Network

# %%
variant = "repnext_m1"
if variant not in timm.list_models("*repnext*"):
    if not Path("RepNeXt").exists():
        subprocess.run(["git", "clone", "--depth", "1", "https://github.com/suous/RepNeXt.git"], check=False)
    sys.path.append("RepNeXt")
    import model.repnext  # registers RepNeXt variants in timm, IMPORTANT
pre = variant in timm.list_models(pretrained=True)
model = timm.create_model(variant, pretrained=pre, num_classes=2)
model.to(DEVICE)
# Out:
# No pretrained configuration specified for repnext_m1 model. Using a default. Please add a config to the model pretrained_cfg registry or pass explicitly.
# RepNext(
#   (stem): RepNextStem(
#     (stem): Sequential(
#       (0): ConvNorm(
#         (conv): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (norm): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): GELU(approximate='none')
#       (2): ConvNorm(
#         (conv): Conv2d(24, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (norm): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (stages): Sequential(
#     (0): RepNextStage(
#       (downsample): Identity()
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#               (conv_3_w): Conv2d(12, 12, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=12)
#               (conv_3_h): Conv2d(12, 12, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=12)
#               (conv_2_2): Conv2d(12, 12, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=12)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(12, 12, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=12)
#               (conv_5_3): Conv2d(12, 12, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=12)
#               (conv_3_5): Conv2d(12, 12, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=12)
#               (conv_7_w): Conv2d(12, 12, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=12, bias=False)
#               (conv_7_h): Conv2d(12, 12, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=12, bias=False)
#               (conv_5_w): Conv2d(12, 12, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=12, bias=False)
#               (conv_5_h): Conv2d(12, 12, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=12, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(12, 12, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=12)
#               (1): Conv2d(12, 12, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=12)
#             )
#           )
#           (norm): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#               (conv_3_w): Conv2d(12, 12, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=12)
#               (conv_3_h): Conv2d(12, 12, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=12)
#               (conv_2_2): Conv2d(12, 12, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=12)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(12, 12, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=12)
#               (conv_5_3): Conv2d(12, 12, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=12)
#               (conv_3_5): Conv2d(12, 12, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=12)
#               (conv_7_w): Conv2d(12, 12, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=12, bias=False)
#               (conv_7_h): Conv2d(12, 12, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=12, bias=False)
#               (conv_5_w): Conv2d(12, 12, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=12, bias=False)
#               (conv_5_h): Conv2d(12, 12, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=12, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(12, 12, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=12)
#               (1): Conv2d(12, 12, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=12)
#             )
#           )
#           (norm): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (2): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#               (conv_3_w): Conv2d(12, 12, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=12)
#               (conv_3_h): Conv2d(12, 12, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=12)
#               (conv_2_2): Conv2d(12, 12, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=12)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(12, 12, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=12)
#               (conv_5_3): Conv2d(12, 12, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=12)
#               (conv_3_5): Conv2d(12, 12, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=12)
#               (conv_7_w): Conv2d(12, 12, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=12, bias=False)
#               (conv_7_h): Conv2d(12, 12, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=12, bias=False)
#               (conv_5_w): Conv2d(12, 12, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=12, bias=False)
#               (conv_5_h): Conv2d(12, 12, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=12, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(12, 12, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=12)
#               (1): Conv2d(12, 12, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=12)
#             )
#           )
#           (norm): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#       )
#     )
#     (1): RepNextStage(
#       (downsample): Downsample(
#         (token_mixer): CopyConv(
#           (conv_s): RepDWConvS(
#             (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48)
#             (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 2), padding=(0, 1), groups=48, bias=False)
#             (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0), groups=48, bias=False)
#             (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1), dilation=(2, 2), groups=48)
#           )
#           (conv_m): RepDWConvM(
#             (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=48)
#             (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1), groups=48)
#             (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(2, 2), padding=(1, 2), groups=48)
#             (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 2), padding=(0, 3), groups=48, bias=False)
#             (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(2, 1), padding=(3, 0), groups=48, bias=False)
#             (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 2), padding=(0, 2), groups=48, bias=False)
#             (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(2, 1), padding=(2, 0), groups=48, bias=False)
#           )
#         )
#         (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (channel_mixer): Sequential(
#           (0): ConvNorm(
#             (conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): GELU(approximate='none')
#           (2): ConvNorm(
#             (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#               (conv_3_w): Conv2d(24, 24, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=24)
#               (conv_3_h): Conv2d(24, 24, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=24)
#               (conv_2_2): Conv2d(24, 24, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=24)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(24, 24, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=24)
#               (conv_5_3): Conv2d(24, 24, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=24)
#               (conv_3_5): Conv2d(24, 24, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=24)
#               (conv_7_w): Conv2d(24, 24, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=24, bias=False)
#               (conv_7_h): Conv2d(24, 24, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=24, bias=False)
#               (conv_5_w): Conv2d(24, 24, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=24, bias=False)
#               (conv_5_h): Conv2d(24, 24, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=24, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(24, 24, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=24)
#               (1): Conv2d(24, 24, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=24)
#             )
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#               (conv_3_w): Conv2d(24, 24, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=24)
#               (conv_3_h): Conv2d(24, 24, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=24)
#               (conv_2_2): Conv2d(24, 24, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=24)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(24, 24, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=24)
#               (conv_5_3): Conv2d(24, 24, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=24)
#               (conv_3_5): Conv2d(24, 24, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=24)
#               (conv_7_w): Conv2d(24, 24, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=24, bias=False)
#               (conv_7_h): Conv2d(24, 24, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=24, bias=False)
#               (conv_5_w): Conv2d(24, 24, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=24, bias=False)
#               (conv_5_h): Conv2d(24, 24, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=24, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(24, 24, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=24)
#               (1): Conv2d(24, 24, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=24)
#             )
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (2): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#               (conv_3_w): Conv2d(24, 24, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=24)
#               (conv_3_h): Conv2d(24, 24, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=24)
#               (conv_2_2): Conv2d(24, 24, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=24)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(24, 24, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=24)
#               (conv_5_3): Conv2d(24, 24, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=24)
#               (conv_3_5): Conv2d(24, 24, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=24)
#               (conv_7_w): Conv2d(24, 24, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=24, bias=False)
#               (conv_7_h): Conv2d(24, 24, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=24, bias=False)
#               (conv_5_w): Conv2d(24, 24, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=24, bias=False)
#               (conv_5_h): Conv2d(24, 24, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=24, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(24, 24, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=24)
#               (1): Conv2d(24, 24, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=24)
#             )
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#       )
#     )
#     (2): RepNextStage(
#       (downsample): Downsample(
#         (token_mixer): CopyConv(
#           (conv_s): RepDWConvS(
#             (conv_3_3): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96)
#             (conv_3_w): Conv2d(96, 96, kernel_size=(1, 3), stride=(1, 2), padding=(0, 1), groups=96, bias=False)
#             (conv_3_h): Conv2d(96, 96, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0), groups=96, bias=False)
#             (conv_2_2): Conv2d(96, 96, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1), dilation=(2, 2), groups=96)
#           )
#           (conv_m): RepDWConvM(
#             (conv_7_7): Conv2d(96, 96, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=96)
#             (conv_5_3): Conv2d(96, 96, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1), groups=96)
#             (conv_3_5): Conv2d(96, 96, kernel_size=(3, 5), stride=(2, 2), padding=(1, 2), groups=96)
#             (conv_7_w): Conv2d(96, 96, kernel_size=(1, 7), stride=(1, 2), padding=(0, 3), groups=96, bias=False)
#             (conv_7_h): Conv2d(96, 96, kernel_size=(7, 1), stride=(2, 1), padding=(3, 0), groups=96, bias=False)
#             (conv_5_w): Conv2d(96, 96, kernel_size=(1, 5), stride=(1, 2), padding=(0, 2), groups=96, bias=False)
#             (conv_5_h): Conv2d(96, 96, kernel_size=(5, 1), stride=(2, 1), padding=(2, 0), groups=96, bias=False)
#           )
#         )
#         (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (channel_mixer): Sequential(
#           (0): ConvNorm(
#             (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): GELU(approximate='none')
#           (2): ConvNorm(
#             (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (2): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (3): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (4): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (5): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (6): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (7): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (8): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (9): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (10): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (11): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (12): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (13): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (14): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#               (conv_3_w): Conv2d(48, 48, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=48)
#               (conv_3_h): Conv2d(48, 48, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=48)
#               (conv_2_2): Conv2d(48, 48, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=48)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(48, 48, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=48)
#               (conv_5_3): Conv2d(48, 48, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=48)
#               (conv_3_5): Conv2d(48, 48, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=48)
#               (conv_7_w): Conv2d(48, 48, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=48, bias=False)
#               (conv_7_h): Conv2d(48, 48, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=48, bias=False)
#               (conv_5_w): Conv2d(48, 48, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=48, bias=False)
#               (conv_5_h): Conv2d(48, 48, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=48, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(48, 48, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=48)
#               (1): Conv2d(48, 48, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=48)
#             )
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#       )
#     )
#     (3): RepNextStage(
#       (downsample): Downsample(
#         (token_mixer): CopyConv(
#           (conv_s): RepDWConvS(
#             (conv_3_3): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192)
#             (conv_3_w): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 2), padding=(0, 1), groups=192, bias=False)
#             (conv_3_h): Conv2d(192, 192, kernel_size=(3, 1), stride=(2, 1), padding=(1, 0), groups=192, bias=False)
#             (conv_2_2): Conv2d(192, 192, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1), dilation=(2, 2), groups=192)
#           )
#           (conv_m): RepDWConvM(
#             (conv_7_7): Conv2d(192, 192, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=192)
#             (conv_5_3): Conv2d(192, 192, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1), groups=192)
#             (conv_3_5): Conv2d(192, 192, kernel_size=(3, 5), stride=(2, 2), padding=(1, 2), groups=192)
#             (conv_7_w): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 2), padding=(0, 3), groups=192, bias=False)
#             (conv_7_h): Conv2d(192, 192, kernel_size=(7, 1), stride=(2, 1), padding=(3, 0), groups=192, bias=False)
#             (conv_5_w): Conv2d(192, 192, kernel_size=(1, 5), stride=(1, 2), padding=(0, 2), groups=192, bias=False)
#             (conv_5_h): Conv2d(192, 192, kernel_size=(5, 1), stride=(2, 1), padding=(2, 0), groups=192, bias=False)
#           )
#         )
#         (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (channel_mixer): Sequential(
#           (0): ConvNorm(
#             (conv): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (1): GELU(approximate='none')
#           (2): ConvNorm(
#             (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#       (blocks): Sequential(
#         (0): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#               (conv_3_w): Conv2d(96, 96, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=96)
#               (conv_3_h): Conv2d(96, 96, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=96)
#               (conv_2_2): Conv2d(96, 96, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=96)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#               (conv_5_3): Conv2d(96, 96, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=96)
#               (conv_3_5): Conv2d(96, 96, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=96)
#               (conv_7_w): Conv2d(96, 96, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=96, bias=False)
#               (conv_7_h): Conv2d(96, 96, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=96, bias=False)
#               (conv_5_w): Conv2d(96, 96, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=96, bias=False)
#               (conv_5_h): Conv2d(96, 96, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=96, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(96, 96, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=96)
#               (1): Conv2d(96, 96, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=96)
#             )
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (1): MetaNeXtBlock(
#           (token_mixer): ChunkConv(
#             (conv_s): RepDWConvS(
#               (conv_3_3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#               (conv_3_w): Conv2d(96, 96, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), groups=96)
#               (conv_3_h): Conv2d(96, 96, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), groups=96)
#               (conv_2_2): Conv2d(96, 96, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1), dilation=(2, 2), groups=96)
#             )
#             (conv_m): RepDWConvM(
#               (conv_7_7): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#               (conv_5_3): Conv2d(96, 96, kernel_size=(5, 3), stride=(1, 1), padding=(2, 1), groups=96)
#               (conv_3_5): Conv2d(96, 96, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2), groups=96)
#               (conv_7_w): Conv2d(96, 96, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=96, bias=False)
#               (conv_7_h): Conv2d(96, 96, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=96, bias=False)
#               (conv_5_w): Conv2d(96, 96, kernel_size=(1, 5), stride=(1, 1), padding=(0, 2), groups=96, bias=False)
#               (conv_5_h): Conv2d(96, 96, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), groups=96, bias=False)
#             )
#             (conv_l): Sequential(
#               (0): Conv2d(96, 96, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=96)
#               (1): Conv2d(96, 96, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=96)
#             )
#           )
#           (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (channel_mixer): Sequential(
#             (0): ConvNorm(
#               (conv): Conv2d(384, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): GELU(approximate='none')
#             (2): ConvNorm(
#               (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (head): RepNextClassifier(
#     (head_drop): Dropout(p=0.0, inplace=False)
#     (head): NormLinear(
#       (norm): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (linear): Linear(in_features=384, out_features=2, bias=True)
#     )
#     (head_dist): NormLinear(
#       (norm): BatchNorm1d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (linear): Linear(in_features=384, out_features=2, bias=True)
#     )
#   )
# )

# %% [markdown]
# ### 6. Training

# %%
a_criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LR)

for epoch in range(1, EPOCHS + 1):
    model.train()
    total, correct, loss_sum = 0, 0, 0.0
    for x, y in train_dl:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        logits = model(x)
        loss = a_criterion(logits, y)
        loss.backward()
        optimizer.step()
        loss_sum += loss.item() * y.size(0)
        preds = logits.argmax(1)
        correct += (preds == y).sum().item()
        total += y.size(0)
    train_acc = correct / total * 100
    train_loss = loss_sum / total

    model.eval()
    with torch.no_grad():
        total, correct, loss_sum = 0, 0, 0.0
        for x, y in val_dl:
            x, y = x.to(DEVICE), y.to(DEVICE)
            logits = model(x)
            loss = a_criterion(logits, y)
            loss_sum += loss.item() * y.size(0)
            preds = logits.argmax(1)
            correct += (preds == y).sum().item()
            total += y.size(0)
    val_acc = correct / total * 100
    val_loss = loss_sum / total
    print(f'Epoch {epoch}/{EPOCHS} | Train L {train_loss:.3f} A {train_acc:.1f}% | Val L {val_loss:.3f} A {val_acc:.1f}%')
# Out:
# Epoch 1/10 | Train L 0.238 A 90.0% | Val L 0.746 A 64.8%
# Epoch 2/10 | Train L 0.165 A 92.4% | Val L 0.198 A 91.9%
# Epoch 3/10 | Train L 0.141 A 94.8% | Val L 0.169 A 94.1%
# Epoch 4/10 | Train L 0.144 A 94.4% | Val L 0.164 A 93.3%
# Epoch 5/10 | Train L 0.105 A 95.7% | Val L 0.128 A 94.4%
# Epoch 6/10 | Train L 0.118 A 95.5% | Val L 0.185 A 91.5%
# Epoch 7/10 | Train L 0.075 A 97.5% | Val L 0.164 A 94.4%
# Epoch 8/10 | Train L 0.086 A 96.9% | Val L 0.147 A 94.1%
# Epoch 9/10 | Train L 0.095 A 96.5% | Val L 0.174 A 93.3%
# Epoch 10/10 | Train L 0.090 A 96.9% | Val L 0.119 A 94.8%

# %% [markdown]
# ### 7. Evaluation & plots

# %%
def report(loader, model, img_size=256):
    model.eval()
    
    print(f"--- Performance Metrics (Standard: {img_size}x{img_size}) ---")
    y_true, y_pred = [], []
    
    # 1. Standard Throughput (Batch Processing at 256x256)
    start_time_total = time.time()
    
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            preds = model(x).argmax(1)
            y_true.extend(y.cpu().tolist())
            y_pred.extend(preds.cpu().tolist())
            
    total_time_set = time.time() - start_time_total

    # Calculate Standard Scores
    cm = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = cm.ravel()
    acc = (tp + tn) / (tp + tn + fp + fn)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    spec = tn / (tn + fp) if (tn + fp) else 0
    fpr = fp / (fp + tn) if (fp + tn) else 0

    print(f'Accuracy   : {acc:.4f}')
    print(f'Precision  : {prec:.4f}')
    print(f'Recall     : {rec:.4f}')
    print(f'F1         : {f1:.4f}')
    print(f'Specificity: {spec:.4f}')
    print(f'FPR        : {fpr:.4f}')
    print("-" * 30)

    print("--- Hardware & Efficiency Metrics ---")
    
    # 2. Parameters
    total_params = sum(p.numel() for p in model.parameters())
    print(f"Parameters             : {total_params:,}")

    # 3. Disk Space (Weights)
    temp_path = "temp_weights.pth"
    torch.save(model.state_dict(), temp_path)
    size_mb = os.path.getsize(temp_path) / (1024 * 1024)
    os.remove(temp_path)
    print(f"Disk Space (Weights)   : {size_mb:.2f} MB")

    # 4. Standard Latency (256x256)
    print(f"Throughput (256x256)   : {len(loader.dataset) / total_time_set:.2f} img/s")
    
    # 5. HIGH RESOLUTION BENCHMARK (1039x1591)
    # We create a dummy tensor of the exact shape you requested to test pure model speed
    # Note: We simulate a single image (Batch Size = 1)
    target_h, target_w = 1038, 1559
    print(f"\n--- High-Resolution Benchmark ({target_h}x{target_w}) ---")
    
    try:
        # Create a dummy image of the specific size
        # Shape: [Batch_Size, Channels, Height, Width]
        high_res_input = torch.randn(1, 3, target_h, target_w).to(DEVICE)
        
        # Calculate FLOPs for this large image
        if profile:
            macs_hr, _ = profile(model, inputs=(high_res_input, ), verbose=False)
            print(f"FLOPs (High Res)       : {macs_hr * 2 / 1e9:.2f} G")
        else:
            print("FLOPs                  : (thop library not installed)")

        # Measure Latency
        print("Measuring High-Res latency...", end="")
        hr_latencies = []
        
        with torch.no_grad():
            # Warmup (critical for large tensors to settle memory)
            for _ in range(3): 
                model(high_res_input)
            
            # Run 10 timing loops
            for _ in range(10):
                t0 = time.time()
                model(high_res_input)
                t1 = time.time()
                hr_latencies.append((t1 - t0) * 1000) # ms
        
        avg_hr_lat = np.mean(hr_latencies)
        std_hr_lat = np.std(hr_latencies)
        print(" Done.")
        print(f"Latency ({target_h}x{target_w}) : {avg_hr_lat:.2f} ms ± {std_hr_lat:.2f} ms")
        print(f"Est. Throughput        : {1000/avg_hr_lat:.2f} img/s")
        
    except RuntimeError as e:
        print(f"\nError: Could not run inference on {target_h}x{target_w}.")
        print(f"This is likely an Out-Of-Memory (OOM) error if the GPU is too small.")
        print(f"Details: {e}")

    # Plot Confusion Matrix
    plt.figure(figsize=(4, 4))
    plt.imshow(cm, cmap='Blues')
    plt.xticks([0, 1], ['No-Feed', 'Feed'])
    plt.yticks([0, 1], ['No-Feed', 'Feed'])
    plt.title('Confusion Matrix')
    for i in range(2):
        for j in range(2):
            plt.text(j, i, cm[i, j], ha='center', va='center')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.tight_layout()
    plt.show()

# Run the report
report(val_dl, model, IMG_SIZE)
# Out:
# --- Performance Metrics (Standard: 256x256) ---
# Accuracy   : 0.9481
# Precision  : 0.9342
# Recall     : 0.9726
# F1         : 0.9530
# Specificity: 0.9194
# FPR        : 0.0806
# ------------------------------
# --- Hardware & Efficiency Metrics ---
# Parameters             : 4,554,856
# Disk Space (Weights)   : 18.02 MB
# Throughput (256x256)   : 65.90 img/s
#
# --- High-Resolution Benchmark (1038x1559) ---
# FLOPs (High Res)       : 56.64 G
# Measuring High-Res latency... Done.
# Latency (1038x1559) : 55.94 ms ± 0.20 ms
# Est. Throughput        : 17.87 img/s
